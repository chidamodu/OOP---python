# %%
import os
os.getcwd()
os.chdir('/Users/chidam/Desktop')

# %%
import pandas as pd
df=pd.read_csv('sponsorlane_fair_copy.csv', encoding='latin-1')
df.head()
# Out:
#    Unnamed: 0                                    company_details  \
# 0           0               About the Company: Visit Our Website
# 1           1               About the Company: Visit Our Website
# 2           2               About the Company: Visit Our Website
# 3           3               About the Company: Visit Our Website
# 4           4   About the Company:Visit Our Website. 40 minut...
#
#                                     sponsored_events  \
# 0   Available Items: Dream Dinners Experience Bas...
# 1   Available Items: Family Portrait Package $300...
# 2   Available Items: Gift CertificateThe Gibbon C...
# 3   Available Items: One Month of Swim LessonsGet...
# 4   Available Items:One Month Unlimited Membershi...
#
#                                     donation_details  \
# 0                                                ...
# 1   Goods Donated: Joel Treadwell Fine Portraitur...
# 2   Goods Donated: Gibbon Conservation Center $10...
# ...

# %%
df1=df.join(df['web_links'].str.split(' ' or '\n', 11, expand=True).rename(columns={0:'link_1', 1:'link_2', 2:'link_3', 3:'link_4', 4:'link_5', 5:'link_6', 6:'link_7', 7:'link_8', 8:'link_9', 9:'link_10', 10:'link_11', 11:'link_12'}))
df1.head()
# Out:
#    Unnamed: 0                                    company_details  \
# 0           0               About the Company: Visit Our Website
# 1           1               About the Company: Visit Our Website
# 2           2               About the Company: Visit Our Website
# 3           3               About the Company: Visit Our Website
# 4           4   About the Company:Visit Our Website. 40 minut...
#
#                                     sponsored_events  \
# 0   Available Items: Dream Dinners Experience Bas...
# 1   Available Items: Family Portrait Package $300...
# 2   Available Items: Gift CertificateThe Gibbon C...
# 3   Available Items: One Month of Swim LessonsGet...
# 4   Available Items:One Month Unlimited Membershi...
#
#                                     donation_details  \
# 0                                                ...
# 1   Goods Donated: Joel Treadwell Fine Portraitur...
# 2   Goods Donated: Gibbon Conservation Center $10...
# ...

# %%
df1.to_csv('SponsorLane_fair_final.csv')
