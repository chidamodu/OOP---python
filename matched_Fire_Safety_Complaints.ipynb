# %%
import pandas as pd
import os
os.getcwd()
os.chdir('/Users/chidam/Desktop')

# %%
df=pd.read_csv('matched_Fire_Safety_Complaints.csv', na_filter=True)
df.head(15)
# Out:
#    Complaint Item Type Description                   Address  Zipcode  \
# 0          uncategorized complaint             460  Ellis St  94102.0
# 1                    alarm systems          3215  Clement St  94121.0
# 2       operating without a permit        705  Divisadero St  94117.0
# 3          uncategorized complaint       372  - 376 Ellis St  94102.0
# 4          uncategorized complaint            228  Duncan St  94131.0
# 5          uncategorized complaint        843  - 855 Clay St  94108.0
# 6                    alarm systems       470  Collingwood St  94114.0
# 7          uncategorized complaint       372  - 376 Ellis St  94102.0
# 8          uncategorized complaint        1464  Davidson Ave  94124.0
# 9                    alarm systems             434  Ellis St  94102.0
# 10         uncategorized complaint          1541  Clement St  94118.0
# 11                   alarm systems            65  Dorland St  94110.0
# ...

# %%
#df.groupby(df['EAS'])
df.head()
# Out:
#   Complaint Item Type Description              Address  Zipcode Battalion  \
# 0         uncategorized complaint        460  Ellis St  94102.0         2
# 1                   alarm systems     3215  Clement St  94121.0         7
# 2      operating without a permit   705  Divisadero St  94117.0         5
# 3         uncategorized complaint  372  - 376 Ellis St  94102.0         3
# 4         uncategorized complaint       228  Duncan St  94131.0         6
#
#   Station Area Received Date Entry Date          Disposition Disposition Date  \
# 0            3        8/4/05     8/4/05  condition corrected          9/20/05
# 1           34      10/31/11   10/31/11  condition corrected         10/31/11
# 2           21       1/28/13    1/28/13  condition corrected          1/28/13
# 3            1       5/25/05    5/31/05  condition corrected          3/21/06
# 4           11      11/29/05   11/29/05     violation issued         11/29/05
#
# ...

# %%
#df.set_index('EAS', inplace=True)
#df.head()

# %%
df_grouped1 =  df.groupby(['EAS']).size().rename('count').reset_index()
df_grouped1.head()
# Out:
#         EAS  count
# 0  274490.0      2
# 1  274495.0      2
# 2  274499.0      2
# 3  274504.0      3
# 4  274512.0      1

# %%
df['Count_of_complaints_per_each_EAS'] = df.groupby('EAS')['EAS'].transform('count')

# %%
df.set_index('EAS', inplace=True)
df.head(15)
# Out:
#          Complaint Item Type Description                   Address  Zipcode  \
# EAS
# 281694.0         uncategorized complaint             460  Ellis St  94102.0
# 304879.0                   alarm systems          3215  Clement St  94121.0
# 296558.0      operating without a permit        705  Divisadero St  94117.0
# 281709.0         uncategorized complaint       372  - 376 Ellis St  94102.0
# 403215.0         uncategorized complaint            228  Duncan St  94131.0
# 458457.0         uncategorized complaint        843  - 855 Clay St  94108.0
# 345881.0                   alarm systems       470  Collingwood St  94114.0
# 281709.0         uncategorized complaint       372  - 376 Ellis St  94102.0
# 374493.0         uncategorized complaint        1464  Davidson Ave  94124.0
# 281691.0                   alarm systems             434  Ellis St  94102.0
# 304251.0         uncategorized complaint          1541  Clement St  94118.0
# ...

# %%
df.to_csv('file_safety_complaints_fair.csv', index=True)
